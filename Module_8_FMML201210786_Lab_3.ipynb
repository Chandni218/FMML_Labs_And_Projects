# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandni218/FMML_Labs_And_Projects/blob/main/Module_8_FMML201210786_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-19 09:50:24--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   127MB/s    in 0.5s
#
# 2022-06-19 09:50:31 (127 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 37329  1703.10926v1  The Android operating system has become the mo...    cs
# 37463  1707.07662v1  We address the challenge of computing search p...    cs
# 9901   1503.02578v2  This paper investigates the effectiveness of f...    cs
# 22873  1709.08770v1  The edge partition model (EPM) is a fundamenta...  stat
# 6726   1705.08621v1  We consider the task of collaborative preferen...  stat
# ...             ...                                                ...   ...
# 15522  1508.02225v2  The widely-used automatic evaluation metrics c...    cs
# 7774   1803.02922v2  Modern supervised learning techniques, particu...  stat
# 6864   1706.10031v1  We propose a new neural sequence model trainin...  stat
# 11785  1701.03449v1  We present Manifold Alignment Determination (M...  stat
# 15326   1312.6173v4  Distributed representations of meaning are a n...    cs
#
#                                                    title  year  \
# 37329  EMULATOR vs REAL PHONE: Android Malware Detect...  2017
# 37463  Towards Real-Time Search Planning in Subsea En...  2017
# 9901   Modeling State-Conditional Observation Distrib...  2015
# 22873  On the Model Shrinkage Effect of Gamma Process...  2017
# 6726                 Nonparametric Preference Completion  2017
# ...                                                  ...   ...
# 15522  Improve the Evaluation of Fluency Using Entrop...  2015
# 7774   Fast Convergence for Stochastic and Distribute...  2018
# 6864   Neural Sequence Model Training via $α$-diverge...  2017
# 11785  Manifold Alignment Determination: finding corr...  2017
# 15326  Multilingual Distributed Representations witho...  2013
#
#                                                 keywords
# 37329  [operating, operating, smartphones, sophistica...
# 37463  [challenge, computing, applications, maximizes...
# 9901   [investigates, effectiveness, factorial, proce...
# 22873  [partition, fundamental, nonparametric, extrac...
# 6726   [collaborative, preference, completion, partia...
# ...                                                  ...
# 15522  [automatic, evaluation, adequately, translatio...
# 7774   [supervised, techniques, particularly, dimensi...
# 6864   [objective, divergence, demonstrate, objective...
# 11785  [alignment, determination, algorithm, alignmen...
# 15326  [distributed, representations, covariance, rel...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 37329    [operating, operating, smartphones, sophistica...
# 37463    [challenge, computing, applications, maximizes...
# 9901     [investigates, effectiveness, factorial, proce...
# 22873    [partition, fundamental, nonparametric, extrac...
# 6726     [collaborative, preference, completion, partia...
#                                ...
# 22726    [representing, classification, constructed, si...
# 27457    [judgments, underlying, understood, distinctio...
# 7489     [canonically, correlated, nonlinear, transform...
# 20044    [heuristics, identifying, intransitive, behavi...
# 21799    [population, migration, information, investmen...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8811 words.
# Out of those 4596 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ccd0d16a-b0e1-4fa9-887e-a656acb05387" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ccd0d16a-b0e1-4fa9-887e-a656acb05387")) {                    Plotly.newPlot(                        "ccd0d16a-b0e1-4fa9-887e-a656acb05387",                        [{"x":["undertaken","sophisticated","investigation","automatically","experiments","countermeasures","algorithms","furthermore","emulation","alleviate","comparative","operating","detection","techniques","implemented","approximately","smartphones","increasingly","malicious","successfully","effectiveness","activities","effectively","avoidance","extracted","detecting","performed","important","maximizes","computation","definition","characterize","infeasible","computing","environments","geographic","applications","challenge","performance","variation","illustrated","measurements","previously","numerical","stationary","distribution","retraining","extension","providing","consideration","improvement","investigates","factorial","conditions","advantage","independently","recognition","observation","independent","compensation","opportunity","considered","appropriate","conditional","automatic","representation","significant","processing","corrupted","suggested","typically","convergence","incorporating","collapsed","overlapping","experimentally","partition","shrinkage","marginalized","generalization","hyperparameters","parameters","efficiently","generative","nonparametric","confirmed","empirically","fundamental","structure","efficiency","overfitted","extracting","indicated","constrained","constructions","dirichlet","intensity","prediction","appropriately","including","expectation","advantages","partially","knowledge","monotonic","algorithm","personalized","collaborative","unobserved","consistent","comparable","transformation","neighbors","neighborhood","factorization","movielens","consistency","preference","associated","completion","lipschitz","locations","rectangular","fundamentally","aggregate","contrasting","information","environment","collecting","maximization","intuitively","assumptions","demonstrate","dimensions","summarizing","davenport","possibility","arbitrarily","optimization","observations","respectively","mechanism","measurement","compressive","satellite","contiguous","efficient","empirical","autonomous","contribution","groupings","variables","relations","challenging","favorably","meaningful","exponentially","increasing","discovers","probability","approaches","discovering","resolving","structures","alternatives","unfolding","characterization","subroutine","recovering","preserving","communication","confidential","modelling","decentralized","stochastic","optimizing","connected","accessing","controlled","synthetic","allocation","shortcomings","databases","immediate","incorporated","attributes","evaluating","different","classification","technique","understand","construction","scalability","classifier","priorities","assignment","relevance","generated","attribute","induction"],"y":[7,29,29,189,650,3,602,176,2,25,40,27,343,362,112,30,6,54,7,80,195,39,122,4,122,91,118,370,12,147,34,41,17,123,96,4,407,149,809,60,22,43,112,91,35,237,15,75,90,27,138,34,4,150,104,41,358,81,129,5,7,134,83,94,174,353,237,299,20,21,103,130,53,2,13,47,27,5,2,112,8,254,160,118,20,9,78,75,333,171,3,72,5,60,4,29,28,211,11,252,34,85,48,350,15,856,10,26,11,82,102,55,21,16,33,2,51,21,105,35,9,38,3,11,23,4,736,121,14,46,14,72,587,39,4,0,33,22,332,85,77,103,23,9,10,0,407,128,56,69,1,129,104,282,22,55,29,100,12,161,443,25,15,112,24,3,27,2,20,54,51,0,59,13,130,64,60,6,40,163,29,16,59,13,23,55,50,734,518,270,58,60,23,148,3,31,39,185,29,17],"type":"bar"},{"x":["undertaken","sophisticated","investigation","automatically","experiments","count ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4596,), (4596, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7966666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Analyzing</span> <span style=''>Business</span> <span style=''>Process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Anomalies</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Autoencoders</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>Businesses</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interested</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.46774193548387094);'>detecting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>anomalies</span> <span style=''>in</span> <span style=''>their</span> <span style=''>internal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>because</span> <span style=''>these</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>indicators</span> <span style=''>for</span> <span style=''>fraud</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>inefficiencies</span> <span style=''>Within</span> <span style=''>the</span> <span style=''>domain</span> <span style=''>of</span> <span style=''>business</span> <span style='background-color:rgba(0, 255, 0, 0.7297297297297298);'>intelligence</span> <span style=''>classic</span> <span style=''>anomaly</span> <span style='background-color:rgba(0, 255, 0, 0.5244444444444445);'>detection</span> <span style=''>is</span> <span style=''>not</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>frequently</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555555);'>researched</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoders</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.46774193548387094);'>detecting</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analyzing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>anomalies</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>occurring</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.7818181818181819);'>execution</span> <span style=''>of</span> <span style=''>a</span> <span style=''>business</span> <span style=''>process</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>does</span> <span style=''>not</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>any</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.36986301369863006);'>knowledge</span> <span style=''>about</span> <span style=''>the</span> <span style=''>process</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style=''>trained</span> <span style=''>on</span> <span style=''>a</span> <span style=''>noisy</span> <span style=''>dataset</span> <span style=''>already</span> <span style='background-color:rgba(0, 255, 0, 0.3975903614457831);'>containing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>anomalies</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3043478260869565);'>effectiveness</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>evaluating</span> <span style=''>it</span> <span style=''>on</span> <span style=''>700</span> <span style='background-color:rgba(0, 255, 0, 0.3418647166361975 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>learning</span> <span style=''>rates</span> <span style=''>with</span> <span style=''>heavy</span> <span style=''>tailed</span> <span style=''>losses</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>fast</span> <span style=''>learning</span> <span style=''>rates</span> <span style=''>when</span> <span style=''>the</span> <span style=''>losses</span> <span style=''>are</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>necessarily</span> <span style=''>bounded</span> <span style=''>and</span> <span style=''>may</span> <span style=''>have</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>with</span> <span style=''>heavy</span> <span style=''>tails</span> <span style=''>To</span> <span style=''>enable</span> <span style=''>such</span> <span style=''>analyses</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>two</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>(i)</span> <span style=''>the</span> <span style=''>envelope</span> <span style=''>function</span> <span style=''>sup</span> <span style=''>f</span> <span style=''>in</span> <span style=''>mathcalF|ell</span> <span style=''>circ</span> <span style=''>f|</span> <span style=''>where</span> <span style=''>ell</span> <span style=''>is</span> <span style=''>the</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>and</span> <span style=''>mathcalF</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>class</span> <span style=''>exists</span> <span style=''>and</span> <span style=''>is</span> <span style=''>Lr</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>integrable</span> <span style=''>and</span> <span style=''>(ii)</span> <span style=''>ell</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>satisfies</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Bernsteins</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <span style=''>on</span> <span style=''>mathcalF</span> <span style=''>Under</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>learning</span> <span style=''>rate</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>O(n</span> <span style=''>12)</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>depending</span> <span style=''>on</span> <span style=''>r</span> <span style=''>and</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Bernsteins</span> <span style=''>powers</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrarily</span> <span style=''>close</span> <span style=''>to</span> <span style=''>O(n</span> <span style=''>1)</span> <span style=''>We</span> <span style=''>then</span> <span style=''>verify</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>and</span> <span style=''>derive</span> <span style=''>fast</span> <span style=''>learning</span> <span style=''>rates</span> <span style=''>for</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>vector</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantization</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>AMIDST</span> <span style=''>a</span> <span style=''>Java</span> <span style=''>Toolbox</span> <span style=''>for</span> <span style=''>Scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style=''>Machine</span> <span style=''>Learning</span> <br/><br/><span style=''>The</span> <span style=''>AMIDST</span> <span style=''>Toolbox</span> <span style=''>is</span> <span style=''>a</span> <span style=''>software</span> <span style=''>for</span> <span style=''>scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>with</span> <span style=''>a</span> <span style=''>spe</span> <span style=''>cial</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>(massive)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>streaming</span> <span style=''>data</span> <span style=''>The</span> <span style=''>toolbox</span> <span style=''>supports</span> <span style=''>a</span> <span style=''>flexible</span> <span style=''>modeling</span> <span style=''>language</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>with</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.36138613861386143);'>variables</span> <span style=''>and</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specified</span> <span style=''>models</span> <span style=''>can</span> <span style=''>be</span> <span style=''>learnt</span> <span style=''>from</span> <span style=''>large</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>using</span> <span style=''>parallel</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style=''>implementa</span> <span style=''>tions</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>either</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>streaming</span> <span style=''>or</span> <span style=''>batch</span> <span style=''>data</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>flexible</span> <span style='background-color:rgba(255, 0, 0, 0.6296296296296297);'>variational</span> <span style=''>message</span> <span style=''>passing</span> <span style=''>scheme</span> <span style=''>which</span> <span style=''>supports</span> <span style=''>discrete</span> <span style=''>and</span> <span style=''>continu</span> <span style=''>ous</span> <span style='background-color:rgba(255, 0, 0, 0.36138613861386143);'>variables</span> <span style=''>from</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>AMIDST</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leverages</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454545);'>functionality</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interfacing</span> <span style=''>to</span> <span style=''>software</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Ensembled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Correlation</span> <span style=''>Between</span> <span style=''>Liver</span> <span style=''>Analysis</span> <span style=''>Outputs</span> <br/><br/><span style=''>Data</span> <span style=''>mining</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>biological</span> <span style=''>analysis</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>spreading</span> <span style=''>for</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>areas</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>the</span> <span style=''>health</span> <span style=''>care</span> <span style=''>and</span> <span style=''>medical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>We</span> <span style=''>have</span> <span style=''>applied</span> <span style=''>the</span> <span style=''>data</span> <span style=''>mining</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>such</span> <span style=''>as</span> <span style=''>KNN</span> <span style=''>SVM</span> <span style=''>MLP</span> <span style=''>or</span> <span style=''>decision</span> <span style=''>trees</span> <span style=''>over</span> <span style=''>a</span> <span style=''>unique</span> <span style=''>dataset</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collected</span> <span style=''>from</span> <span style=''>16380</span> <span style=''>analysis</span> <span style=''>results</span> <span style=''>for</span> <span style=''>a</span> <span style=''>year</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>have</span> <span style=''>also</span> <span style=''>used</span> <span style=''>meta</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>to</span> <span style=''>question</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increased</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>rate</span> <span style=''>between</span> <span style=''>the</span> <span style=''>liver</span> <span style=''>disorder</span> <span style=''>and</span> <span style=''>the</span> <span style=''>liver</span> <span style=''>analysis</span> <span style=''>outputs</span> <span style=''>The</span> <span style=''>results</span> <span style=''>show</span> <span style=''>that</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>among</span> <span style=''>ALT</span> <span style=''>AST</span> <span style=''>Billirubin</span> <span style=''>Direct</span> <span style=''>and</span> <span style=''>Billirubin</span> <span style=''>Total</span> <span style=''>down</span> <span style=''>to</span> <span style=''>15</span> <span style=''>of</span> <span style=''>error</span> <span style=''>rate</span> <span style=''>Also</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficient</span> <span style=''>is</span> <span style=''>up</span> <span style=''>to</span> <span style=''>94</span> <span style=''>This</span> <span style=''>makes</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>results</span> <span style=''>from</span> <span style=''>each</span> <span style=''>other</span> <span style=''>or</span> <span style=''>disease</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10093056549749463)
# 	segmentation (0.0654974946313529)
# 	representation (0.12634216177523264)
# 	processing (0.1070150322118826)
# 	architecture (0.08052970651395848)
# 	detection (0.1227630637079456)
# 	information (0.2634216177523264)
# 	different (0.262705798138869)
# 	recognition (0.12813171080887617)
# 	convolutional (0.13743736578382248)
#
# Some Statistics words are:
# 	statistical (0.14705882352941177)
# 	stochastic (0.1365902293120638)
# 	variables (0.1370887337986042)
# 	variational (0.10967098703888335)
# 	estimation (0.16849451645064806)
# 	distribution (0.18095712861415753)
# 	theoretical (0.1550348953140578)
# 	dimensional (0.1839481555333998)
# 	inference (0.2053838484546361)
# 	regression (0.18993020937188435)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f2217640-0952-4069-a3a5-98763b04a494" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2217640-0952-4069-a3a5-98763b04a494")) {                    Plotly.newPlot(                        "f2217640-0952-4069-a3a5-98763b04a494",                        [{"x":["undertaken","sophisticated","investigation","automatically","experiments","countermeasures","algorithms","furthermore","emulation","alleviate","comparative","operating","detection","techniques","implemented","approximately","smartphones","increasingly","malicious","successfully","effectiveness","activities","effectively","avoidance","extracted","detecting","performed","important","maximizes","computation","definition","characterize","infeasible","computing","environments","geographic","applications","challenge","performance","variation","illustrated","measurements","previously","numerical","stationary","distribution","retraining","extension","providing","consideration","improvement","investigates","factorial","conditions","advantage","independently","recognition","observation","independent","compensation","opportunity","considered","appropriate","conditional","automatic","representation","significant","processing","corrupted","suggested","typically","convergence","incorporating","collapsed","overlapping","experimentally","partition","shrinkage","marginalized","generalization","hyperparameters","parameters","efficiently","generative","nonparametric","confirmed","empirically","fundamental","structure","efficiency","overfitted","extracting","indicated","constrained","constructions","dirichlet","intensity","prediction","appropriately","including","expectation","advantages","partially","knowledge","monotonic","algorithm","personalized","collaborative","unobserved","consistent","comparable","transformation","neighbors","neighborhood","factorization","movielens","consistency","preference","associated","completion","lipschitz","locations","rectangular","fundamentally","aggregate","contrasting","information","environment","collecting","maximization","intuitively","assumptions","demonstrate","dimensions","summarizing","davenport","possibility","arbitrarily","optimization","observations","respectively","mechanism","measurement","compressive","satellite","contiguous","efficient","empirical","autonomous","contribution","groupings","variables","relations","challenging","favorably","meaningful","exponentially","increasing","discovers","probability","approaches","discovering","resolving","structures","alternatives","unfolding","characterization","subroutine","recovering","preserving","communication","confidential","modelling","decentralized","stochastic","optimizing","connected","accessing","controlled","synthetic","allocation","shortcomings","databases","immediate","incorporated","attributes","evaluating","different","classification","technique","understand","construction","scalability","classifier","priorities","assignment","relevance","generated","attribute","induction","abstraction","improvements","education","molecular","recasting","procedure","performing","provision","compounds","hypothesis","consistently","pathology","framework","continuous","mathematical","prospective","leverages","challenges","formulation","candidates","properties","inaccessible","experimentation","simultaneously","intractable","experiment","resampling","introduce","sequential","maximizing","asymptotically","approximation","nonlinear","parametric","estimating","theoretically","computationally","converges","exploiting","expensive","recordings","transcription","polyphonic","describes","inference","comparisons","evaluations","outperformed","conference","probabilities","influence","accuracies","available","description","classic ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	davenport
# 	contiguous
# 	confidential
# 	spectroradiometer
# 	robustification
# 	distributionally
# 	operationalize
# 	schizophrenia
# 	marginalize
# 	commutative
# 	forthcoming
# 	memberships
# 	stratifying
# 	traintest
# 	transferability
# 	emphstructured
# 	reversing
# 	degeneracy
# 	underestimation
# 	nomination
# Some words which never appear in Statistics papers:
# 	undertaken
# 	countermeasures
# 	emulation
# 	avoidance
# 	geographic
# 	priorities
# 	subjected
# 	particularities
# 	conversations
# 	fortunately
# 	intentional
# 	pixelwise
# 	nonmonotonic
# 	revisions
# 	deblurring
# 	hallucinate
# 	visibility
# 	invisible
# 	backdoors
# 	meticulous

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.073518564052127e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
